# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiHunts/ComputerVision/blob/main/image_operations_using_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %% [markdown]
# # Loading and displaying an image

# %%
image = cv2.imread('6.jpg')
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
(h,w,d)=image.shape
print("width=",w,"height=",h,"depth=",d)
# Out:
# width= 509 height= 339 depth= 3

# %%
#cv2.imshow("Goeduhub",image)
#cv2.waitKey(0)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FD8FE4DFF50>

# %%
#to check datatype of image
type(image)
# Out:
# numpy.ndarray

# %%
#check data type of values
image.dtype
# Out:
# dtype('uint8')

# %%
shape = image.shape
#height
height = image.shape[0]
width = image.shape[1]
channels = image.shape[2]
cv2_imshow(image[:,:,2])
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7FD8FE476E10>

# %%
(B,G,R) = image[50,100]
print("R=",R)
print("B=",B)
print("G=",G)
# Out:
# R= 90
# B= 68
# G= 84

# %% [markdown]
# ## Remove Red Color From image

# %%
image[:,:,2] = 0
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FD8FE476E50>

# %%
import cv2
import numpy as np
a = np.zeros((300,300,3),dtype='uint8')
a[:]=[207,56,63]
a[100:300,50:150]=[0,240,255]
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FD8FE47D7D0>

# %%
#resize the image to 200x200 px, ignoring the aspect ratio
resized = cv2.resize(image,(400,400))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD8FE483710>

# %%
cv2.imwrite('resized.png',resized)
# Out:
# True

# %% [markdown]
# # Changing Color using OpenCV

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7FD8FD457910>

# %%
import cv2
image= cv2.imread('6.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FD8FD3F4190>

# %%
hflip = cv2.flip(image,-1)
cv2_imshow(hflip)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FD8FD457BD0>

# %%
import cv2
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml") 
# faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

img = cv2.imread('faces.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faces = faceCascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(20, 20))
print(faces)
# Out:
# [[364  32  54  54]
#  [ 74  49  57  57]
#  [164  57  52  52]
#  [310  72  47  47]
#  [241  84  50  50]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FD8FE47D110>
